# %%
x = sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x = sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import keyword 
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import math 
math.sqrt(25)
# Out:
# 5.0

# %%
round(math.sqrt(25))
# Out:
# 5

# %%
math.floor(3.8)
# Out:
# 3

# %%
math.ceil(3.8)
# Out:
# 4

# %%
pow(3,2)
# Out:
# 9

# %%
pi = 3.17    
pi
# Out:
# 3.17

# %%
math.pi
# Out:
# 3.141592653589793

# %%
help()  # it is to use for any information in python and use q for quit
# Out:
# Welcome to Python 3.13's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.13/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q", "quit" or "exit".
# help>  topics
# Here is a list of available topics.  Enter any topic name to get more help.
#
# ASSERTION                 EXCEPTIONS                PACKAGES
# ASSIGNMENT                EXECUTION                 POWER
# ASSIGNMENTEXPRESSIONS     EXPRESSIONS               PRECEDENCE
# ...

# %%
help()
# Out:
# Welcome to Python 3.13's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.13/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q", "quit" or "exit".
# help>  math funtions
# No Python documentation found for 'math funtions'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
# help>  q
# You are now leaving help and returning to the Python interpreter.
# ...

# %%
m.sqrt(49)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 m.sqrt(49)
#
# NameError: name 'm' is not defined

# %%
math.sqrt(49)
# Out:
# 7.0

# %%
import math as m

# %%
m.sqrt(49)
# Out:
# 7.0

# %%
import nareshitechnology as nit
import indiantechhnology mumbai as iitm
# Out:
#   Cell In[19], line 1
#     import nareshitechnology as nit'
#                                    ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
from math import sqrt, pow  # math has many function if you want to import specific function 
print(pow(2,3))
print(m.sqrt(10))
# Out:
# 8.0
# 3.1622776601683795

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# input()

# %%
input()
# Out:
#  hello
# 'hello '

# %%
input()
input()
# Out:
#  hello
#  hi
# 'hi'

# %% [raw]
# x = input()
# y = input()
# z = x + y
# print(z)

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
x1 = input('enter the 1st number')
x2 = input('enter the 2nd number')      
x3 = x1+x2
print(x3)
# Out:
# enter the 1st number 10
# enter the 2nd number 20
# 1020

# %%
x1 = int(input('enter the 1st number'))
x2 = int(input('enter the 2nd number'))      
x3 = x1+x2
print(x3)
# Out:
# enter the 1st number 10
# enter the 2nd number 20
# 30

# %%
st = input('enter a string')[0]
print(st)
# Out:
# enter a string hello
# h

# %%
st = input('enter a string')[0:2]
print(st)
# Out:
# enter a string hello
# he

# %%
st = input('enter a string')[9:13]
print(st)
# Out:
# enter a string 1234567890
# 0

# %%
st = input('enter a string')[9:13]
print(st)
# Out:
# enter a string welcometonaresh
# nare

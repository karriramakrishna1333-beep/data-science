# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split, cross_val_score
from io import StringIO


path = r'C:\Users\Jagatjyoti\Jagat_Code\09-04-2026\archive (1)\movie.csv'
imdb_movie = pd.read_csv(path)
imdb_movie.shape
# Out:
# (27278, 3)

# %%
path1 = r'C:\Users\Jagatjyoti\Jagat_Code\09-04-2026\archive (1)\rating.csv'
imdb_rating = pd.read_csv(path1)
imdb_rating.shape
# Out:
# (1048575, 4)

# %%
path2 = r'C:\Users\Jagatjyoti\Jagat_Code\09-04-2026\archive (1)\tag.csv'
imdb_tag = pd.read_csv(path2)
imdb_tag.shape
# Out:
# (465564, 4)

# %%
print(imdb_tag.columns)
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
print(imdb_rating.columns)
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
print(imdb_movie.columns)
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
imdb_tag.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
imdb_tag.iloc[0]
# Out:
# userId                        18
# movieId                     4141
# tag                  Mark Waters
# timestamp    2009-04-24 18:19:40
# Name: 0, dtype: object

# %%
imdb_tag.iloc[1]
# Out:
# userId                        65
# movieId                      208
# tag                    dark hero
# timestamp    2013-05-10 01:41:18
# Name: 1, dtype: object

# %%
tag_row_0 =imdb_tag.iloc[0]

# %%
tag_row_0
# Out:
# userId                        18
# movieId                     4141
# tag                  Mark Waters
# timestamp    2009-04-24 18:19:40
# Name: 0, dtype: object

# %%
print(tag_row_0['userId'])
# Out:
# 18

# %%
def greet():
    print("Welcome to ...DS class")

# %%
greet()
# Out:
# Welcome to ...DS class

# %%
def greet():
    print("Welcome to ...DS class")
greet()
def greet():
    print("Welcome to ...DS class")
      print("Good bye..Boss")
greet()
# Out:
# Welcome to ...DS class
# Welcome to ...DS class

# %%
greet()
greet()
# Out:
# Welcome to ...DS class
# Welcome to ...DS class

# %%
greet()
greet()
greet()
# Out:
# Welcome to ...DS class
# Welcome to ...DS class
# Welcome to ...DS class

# %%
def greet():
    print("Welcome to ...DS class")
    print("Good bye..Boss")

greet()
greet()
greet()
# Out:
# Welcome to ...DS class
# Good bye..Boss
# Welcome to ...DS class
# Good bye..Boss
# Welcome to ...DS class
# Good bye..Boss

# %%
def add(x,y): # x, y formal argument
    c=x+y
    print(c)
add(4,5) # Actual argument
# Out:
# 9

# %%
def add(x,y):
    c=x+y
    print(c)
add(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 4
#       2     c=x+y
#       3     print(c)
# ----> 4 add(4)
#
# TypeError: add() missing 1 required positional argument: 'y'

# %%
def add(x):
    c=x+y
    print(c)
add(4,6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 4
#       2     c=x+y
#       3     print(c)
# ----> 4 add(4,6)
#
# TypeError: add() takes 1 positional argument but 2 were given

# %%
def add(x,y):
    c=x+y
    print(c)
add(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 4
#       2     c=x+y
#       3     print(c)
# ----> 4 add(4)
#
# TypeError: add() missing 1 required positional argument: 'y'

# %%
def add(x,y):
    c=x+y
    print(c)
add(5,6)
# Out:
# 11

# %%
def add(x,y):
    c=x+y
    print(c)
add(5,6)
# Out:
# 11

# %%
def add(x,y):
    c=x+y
    return(c)
add(5,6)
# Out:
# 11

# %%
def add(x,y):
    c=x+y
    return c
add(5,6)
# Out:
# 11

# %%
def add(x,y):
    c=x+y
    return c
result  = add(5,6)
print(result)
print(type(result))
# Out:
# 11
# <class 'int'>

# %%
def add(x,y):
    c=x+y
    return c
result  = add(5,6)
print(result)
print(type(result))
# Out:
# 11
# <class 'int'>

# %%
def myFun(*args, **kwargs):
    print("Non-Keyword Arguments (*args):")
    for arg in args:
        print(arg)

    print("\nKeyword Arguments (**kwargs):")
    for key, value in kwargs.items():
        print(f"{key} == {value}")

myFun('Hey', 'Welcome', first='Geeks', mid='for', last='Geeks')
# Out:
# Non-Keyword Arguments (*args):
# Hey
# Welcome
#
# Keyword Arguments (**kwargs):
# first == Geeks
# mid == for
# last == Geeks

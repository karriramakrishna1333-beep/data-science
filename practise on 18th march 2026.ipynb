# %%
exp = input('enter a value')
print(exp)
# Out:
# enter a value 2 + 3 - 1 + 10
# 2 + 3 - 1 + 10

# %%
exp = int(input('enter a value'))
print(exp)
# Out:
# enter a value 2 + 3 - 1 + 10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 exp = int(input('enter a value'))
#       2 print(exp)
#
# ValueError: invalid literal for int() with base 10: '2 + 3 - 1 + 10'

# %%
exp = eval(input('enter a value'))
print(exp)
# Out:
# enter a value 2
# 2

# %%
exp = eval(input('enter a value'))
print(exp)
# Out:
# enter a value 2 + 3 - 1 + 10
# 14

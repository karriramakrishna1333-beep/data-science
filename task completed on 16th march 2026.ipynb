# %% [markdown]
# Bit Wise operator

# %%
-3 + 1
# Out:
# -2

# %%
a = 3
-a
# Out:
# -3

# %% [markdown]
# Bit wise and OR

# %%
12 & 20
# Out:
# 4

# %%
12 | 13
# Out:
# 13

# %% [markdown]
# xor( xclusive or )

# %%
25 ^ 30
# Out:
# 7

# %%
12 ^ 13
# Out:
# 1

# %%
12 << 1    # in leftshift we gain the bit
# Out:
# 24

# %%
12 << 2
# Out:
# 48

# %%
25 << 1
# Out:
# 50

# %%
bin(25)
# Out:
# '0b11001'

# %%
12 >> 1    # in rightshift we loose the bit
# Out:
# 6

# %%
13 >> 1
# Out:
# 6

# %%
13 >> 3
# Out:
# 1

# %%
25 >> 2
# Out:
# 6

# %% [markdown]
# Print format method

# %%
num1=20
num2=30
add=num1+num2
print(add)
# Out:
# 50

# %%
num1=20
num2=30
add=num1+num2

print('The Addition of {} and {} is = {}').format(num1, num2, add)
# Out:
# The Addition of {} and {} is = {}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 5
#       2 num2=30
#       3 add=num1+num2
# ----> 5 print('The Addition of {} and {} is = {}').format(num1, num2, add)
#
# AttributeError: 'NoneType' object has no attribute 'format'

# %% [markdown]
# f string method

# %%
num4 = 10
num5 = 20
add = num4+num5
print( 'the addition of (num4) (num5) (add)')
# Out:
# the addition of (num4) (num5) (add)

# %%
num4 = 10
num5 = 20
add = num4+num5
print(add)
# Out:
# 30

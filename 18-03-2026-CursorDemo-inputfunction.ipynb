# %%
x1 = input('Enter the first number')
y1 = input('Enter the Second number')
z = x1+y1
print(z)
# Out:
# Enter the first number 12
# Enter the Second number 13
# 1213

# %%
x1 = int(input('Enter the first number'))
y1 = int(input('Enter the Second number'))
z = x1+y1
print(z)
# Out:
# Enter the first number 12
# Enter the Second number 13
# 25

# %%
x1 = input('Input a Stting')[0]
x1
# Out:
# Input a Stting abcd
# 'a'

# %%
#18th class input()

# %%
exp = input('Enter a value')
print(exp)
# Out:
# Enter a value 2+3-1+10
# 2+3-1+10

# %%
exp1 = int(input('Enter a value'))
print(exp1) # will get value error
# Out:
# Enter a value 1+3+5-1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 exp1 = int(input('Enter a value'))
#       2 print(exp1)
#
# ValueError: invalid literal for int() with base 10: '1+3+5-1'

# %%
exp1 = eval(input('Enter a value'))
print(exp1) # work as we used eval;
# Out:
# Enter a value 3+5+7-10
# 5

# %%
#write a pyton program to add two numbers

a = 10
b = 20
c = a + b
print(c)
# Out:
# 30

# %%
#write a calculator app for me in python

import tkinter as tk
from tkinter import ttk

root = tk.Tk()
root.title("Calculator")
root.geometry("300x200")

label = tk.Label(root, text="Calculator")
label.pack()

root.mainloop()

# %%
#write a front end code for me for the calculator app

import tkinter as tk
from tkinter import ttk

root = tk.Tk()
root.title("Calculator")
root.geometry("300x200")

label = tk.Label(root, text="Calculator")
label.pack()

root.mainloop()

# %% [markdown]
# list datastructure

# %%
l = []                                               #empty list
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
type(12)
# Out:
# int

# %%
l.append(10) n                                      # execute only one time,if we execute two times it gives two values

# %%
l
# Out:
# [10, 10]

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)

# %%
l
# Out:
# [10, 10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 6

# %%
l.append(10)

# %%
l
# Out:
# [10, 10, 20, 30, 40, 50, 10]

# %%
l1 = [10, 2.3, 1+2j, True, 'nit', [1,2,3]]                         # we can define multiple values

# %%
l1
# Out:
# [10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]

# %%
len(l1)
# Out:
# 6

# %%
print(l)
print(l1)
# Out:
# [10, 10, 20, 30, 40, 50, 10]
# [10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]

# %%
print(id(l))
print(id(l1))
# Out:
# 1766760718080
# 1766761914304

# %%
l
# Out:
# [10, 10, 20, 30, 40, 50, 10]

# %%
l2                                                              #error because we not defined l2 below
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l2 = l.copy()                                                  #if we not defined the value before we should use .copy()
l2
# Out:
# [10, 10, 20, 30, 40, 50, 10]

# %%
print(id(l))
print(id(l1))
print(id(l2))
# Out:
# 1766760718080
# 1766761914304
# 1766768465984

# %%
l2
# Out:
# [10, 10, 20, 30, 40, 50, 10]

# %%
len(l2)
# Out:
# 7

# %%
l2.clear()                                                      # clear is used to clear ther values

# %%
l2
# Out:
# []

# %%
len(l2)
# Out:
# 0

# %%
del l2                                                          # del is uded to delete the values

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l.count(20)                                                # use shift + tab to see the fuction how it is used, count is used for count of a element
# Out:
# 1

# %%
l.count(10)
# Out:
# 3

# %%
l.count(100)
# Out:
# 0

# %%
l.count(30)
# Out:
# 1

# %%
a = [1,2,3]
b = [4,5,6]
a.extend(b)

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l2 = []

# %%
print(l)
print(l1)
print(l2)
# Out:
# [10, 10, 20, 30, 40, 50, 10]
# [10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]
# [10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]

# %%
l
# Out:
# [10, 10, 20, 30, 40, 50, 10]

# %%
l[0]
# Out:
# 10

# %%
l[0] = 100

# %%
l[0]
# Out:
# 100

# %%
l                         # list is mutable
# Out:
# [100, 10, 20, 30, 40, 50, 10]

# %%
job = [5000]              # it is known as mutable 
job
# Out:
# [5000]

# %%
job[0]
# Out:
# 5000

# %%
job[0] = 1000

# %%
job
# Out:
# [1000]

# %%
l[-2] = 500
l
# Out:
# [100, 10, 20, 30, 40, 500, 10]

# %%
l.pop
# Out:
# <function list.pop(index=-1, /)>

# %%
l.insert
# Out:
# <function list.insert(index, object, /)>

# %%
l.index(100)
# Out:
# 0

# %%
l2
# Out:
# [10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]

# %%
l2.index(10)                # it shows where the value is placed
# Out:
# 0

# %%
l2.index(2.3)
# Out:
# 1

# %%
l.insert(2,15)             # insert adds the number in between

# %%
l
# Out:
# [100, 10, 15, 30, 20, 30, 40, 500, 10]

# %%
l.pop()                     # pop delete the last elements
# Out:
# 10

# %%
l2
# Out:
# [10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]

# %%
l2.pop()
# Out:
# [1, 2, 3]

# %%
l2
# Out:
# [10, 2.3, (1+2j), True, 'nit']

# %%
l2.pop()
# Out:
# 'nit'

# %%
l2
# Out:
# [10, 2.3, (1+2j), True]

# %%
l2.pop()
# Out:
# True

# %%
l2
# Out:
# [2.3, (1+2j)]

# %%
l2.pop(1)
# Out:
# (1+2j)

# %%
l2
# Out:
# [2.3]

# %%
l2.remove(2.3)

# %%
l2
# Out:
# []

# %%
l.reverse()                          # it reverse the elements

# %%
l
# Out:
# [500, 40, 30, 20, 30, 15, 10, 100]

# %%
l.sort()                            # sort is used for accending order

# %%
l
# Out:
# [10, 15, 20, 30, 30, 40, 100, 500]

# %%
l.sort(reverse=True)               # it is used for decending order
l
# Out:
# [500, 100, 40, 30, 30, 20, 15, 10]

# %%
l.pop(2)
# Out:
# 40

# %%
l
# Out:
# [500, 100, 30, 30, 20, 15, 10]

# %%
l3 = [10, 20, [2,3],3]

# %%
l3[2] = [2]
l3
# Out:
# [10, 20, [2], 3]

# %%
30 in l
# Out:
# True

# %%
5000 in l
# Out:
# False

# %%
l
# Out:
# [500, 100, 30, 30, 20, 15, 10]

# %%
for i in l:                  
    print(i)
# Out:
# 500
# 100
# 30
# 30
# 20
# 15
# 10

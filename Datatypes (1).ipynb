# %%
    #variable starts with Alphabets only, cannot start with numbers.
    # Ex;
    '''
    1Nit = 10
    1Nit
    '''
    Nit1 = 19
    Nit1
# Out:
# 19

# %% [markdown]
# DATATYPES:

# %% [markdown]
# 1. INTEGER DATATYPE:

# %%
   i = 5
   #  5 = i cannot be possible in python
   # type()
   type(i)
# Out:
# int

# %%
   id(i)
# Out:
# 140726057280552

# %%
   id(5)
# Out:
# 140726057280552

# %% [markdown]
#     2.FLOAT DATATYPE:

# %%
   f = 110.45
   type(f)
# Out:
# float

# %%
  # # in float , only e is allowed. e--> exponential
  # e power 0--> 1.0
  # e power 1--> 10.0
  # e power 2--> 100.0
  # e power 3--> 1000.0
  # etc.....

# %%
  f1 = 2.4e1
  f1
# Out:
# 24.0

# %%
  f2 = 5.8e3
  f2
# Out:
# 5800.0

# %%
  f3 = 6.7e8
  f3
# Out:
# 670000000.0

# %%
  f4 = 6.893e5
  f4
# Out:
# 689300.0

# %% [markdown]
#    3. BOOLEAN VALUE

# %%
  # When we use ((+,-,/,*)) operators, then it will convert true as 1 , false as 0.

# %%
  # True = 1, False = 0.
 True + False
# Out:
# 1

# %%
  False/True   # Float division
# Out:
# 0.0

# %%
  False//True  # Integer division
# Out:
# 0

# %%
  int(True)
# Out:
# 1

# %%
  #True/False   ## This will give run-time error.

# %% [markdown]
#    4. COMPLEX DATATYPE

# %%
   # Complex Datatype has "Real Part and Imaginary Part".
      Form: a + bj where a, b are integers.
   #   Ex: 20 + 10j  . Here, 20 is called Real Part, and 10 is called Imaginary part, where j = Square root of -1.

# %%
  c = 30 + 40j
  c.real
# Out:
# 30.0

# %%
  c.imag
# Out:
# 40.0

# %%
  c = 1+3j
  c1 = 3+4j
  c+c1                     # real part will add with real, imaginary will add with imaginary only.
# Out:
# (4+7j)

# %%
  python is dynamic because it will understand things by itself.

# %% [markdown]
#    5. STRING

# %%
  non technical -- number (int)
  text   -- string

# %%
  string must be declared with single '' | "" | ''' '''|.
 1. ' ' ,  " " --> single coat, bouble coat works when we have single line comment.
 2
